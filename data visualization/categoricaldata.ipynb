# %% [markdown]
# Categorical data plots are used to visualize data where variables are categories (groups) instead of continuous numbers.
# * boxplot
# * violinplot
# * stripplot
# * swarmplot
# * barplot
# * countplot

# %%
import seaobrn
